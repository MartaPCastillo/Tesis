# %% [markdown]
# <a href="https://colab.research.google.com/github/MartaPCastillo/Tesis/blob/main/Tendencia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf # Para descargar datos de acciones

# %%
#1. Obtener datos
df = yf.download('GMEXICOB.MX', start='2025-01-01')
# Out:
# /tmp/ipykernel_3023/2387032082.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download('GMEXICOB.MX', start='2025-01-01')
# [*********************100%***********************]  1 of 1 completed

# %%
#2. Calcular Media Móvil Simple de 150 días
df['SMA150'] = df['Close'].rolling(window=150).mean()

# %%
#3. Calcular Media Móvil Exponencial de 150 días
df['EMA150'] = df['Close'].ewm(span=150, adjust=False).mean()

# %%
#Visualizar
df[['Close', 'SMA150', 'EMA150']].plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Date'>
